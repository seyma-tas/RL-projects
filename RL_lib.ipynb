# %%
# !pip install ray[rllib]
# Out:
# Collecting ray[rllib]
#   Downloading https://files.pythonhosted.org/packages/e6/37/a9af3781b41cc2d9b98125c20a3d90e712e8dbe980bf86c6ae37eb9aa65d/ray-1.2.0-cp37-cp37m-macosx_10_13_intel.whl (47.8MB)
#      |████████████████████████████████| 47.9MB 8.4MB/s eta 0:00:011
# Collecting colorful (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/b0/8e/e386e248266952d24d73ed734c2f5513f34d9557032618c8910e605dfaf6/colorful-0.5.4-py2.py3-none-any.whl (201kB)
#      |████████████████████████████████| 204kB 22.1MB/s eta 0:00:01
# Collecting py-spy>=0.2.0 (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/14/4a/f11c5e21ed57a7e6545f5ec995eeff033c44ac685195ca512bd81f69ab54/py_spy-0.3.4-py2.py3-none-macosx_10_14_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 38.2MB/s eta 0:00:01
# Requirement already satisfied: prometheus-client>=0.7.1 in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (0.7.1)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/f9/12/d6ddfec3cf6b8b83ed89368e88bab1afcff9120090b407e1c1a09549010b/msgpack-1.0.2-cp37-cp37m-macosx_10_14_x86_64.whl (72kB)
#      |████████████████████████████████| 81kB 19.1MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16 in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (1.17.2)
# Collecting aiohttp-cors (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/13/e7/e436a0c0eb5127d8b491a9b83ecd2391c6ff7dcd5548dfaec2080a2340fd/aiohttp_cors-0.7.0-py3-none-any.whl
# Requirement already satisfied: grpcio>=1.28.1 in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (1.29.0)
# Collecting gpustat (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/b4/69/d8c849715171aeabd61af7da080fdc60948b5a396d2422f1f4672e43d008/gpustat-0.6.0.tar.gz (78kB)
#      |████████████████████████████████| 81kB 13.0MB/s eta 0:00:01
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (3.0.12)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (3.12.2)
# Collecting aioredis (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/b0/64/1b1612d0a104f21f80eb4c6e1b6075f2e6aba8e228f46f229cfd3fdac859/aioredis-1.3.1-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 16.5MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (2.22.0)
# Collecting redis>=3.5.0 (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 22.6MB/s eta 0:00:01
# Requirement already satisfied: jsonschema in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (3.0.2)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (7.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (5.1.2)
# Collecting opencensus (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/e2/d6/b952f11b29c3a0cbec5620de3c4260cecd8c4329d83e91587edb48691e15/opencensus-0.7.12-py2.py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 34.5MB/s eta 0:00:01
# Collecting aiohttp (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/66/03/1635f2395076c15ae2c0826fbd21c70498d2f10ba650726fae900b6e990f/aiohttp-3.7.4-cp37-cp37m-macosx_10_14_x86_64.whl (644kB)
#      |████████████████████████████████| 645kB 29.8MB/s eta 0:00:01
# Requirement already satisfied: colorama in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (0.4.1)
# Requirement already satisfied: pandas; extra == "rllib" in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (0.25.1)
# Collecting lz4; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/29/65/eebeef42498cdb5657c75381d1c576d01313f096804ee14fd62986b9c0c7/lz4-3.1.3-cp37-cp37m-macosx_10_9_x86_64.whl (261kB)
#      |████████████████████████████████| 266kB 32.8MB/s eta 0:00:01
# Requirement already satisfied: scipy; extra == "rllib" in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (1.4.1)
# Collecting tensorboardX; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/af/0c/4f41bcd45db376e6fe5c619c01100e9b7531c55791b7244815bac6eac32c/tensorboardX-2.1-py2.py3-none-any.whl (308kB)
#      |████████████████████████████████| 317kB 35.5MB/s eta 0:00:01
# Requirement already satisfied: tabulate; extra == "rllib" in /opt/anaconda3/lib/python3.7/site-packages (from ray[rllib]) (0.8.7)
# Collecting gym[atari]; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/26/f2/e7ee20bf02b2d02263becba1c5ec4203fef7cfbd57759e040e51307173f4/gym-0.18.0.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 32.6MB/s eta 0:00:01
# Collecting dm-tree; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/13/c2/079b00ebf0cfb7804df3e7547d4e24ad0142d81ed178716a651c33ccc632/dm_tree-0.1.5-cp37-cp37m-macosx_10_9_x86_64.whl (94kB)
#      |████████████████████████████████| 102kB 23.0MB/s ta 0:00:01
# Collecting atari-py; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/f9/bb/b01e780ac5abc41f41b37faeaa005fcdabffe37713d943f86190305c8294/atari_py-0.2.6-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.5MB)
#      |████████████████████████████████| 3.5MB 10.3MB/s eta 0:00:01
# Collecting opencv-python-headless<=4.3.0.36; extra == "rllib" (from ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/2e/16/99fa0a5e7cdf138a62768252e361aa24b88151e5a7010efc5b3f4e0d0811/opencv_python_headless-4.3.0.36-cp37-cp37m-macosx_10_9_x86_64.whl (43.7MB)
#      |████████████████████████████████| 43.7MB 20.7MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5.2 in /opt/anaconda3/lib/python3.7/site-packages (from grpcio>=1.28.1->ray[rllib]) (1.12.0)
# Collecting nvidia-ml-py3>=7.352.0 (from gpustat->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/6d/64/cce82bddb80c0b0f5c703bbdafa94bfb69a1c5ad7a79cff00b482468f0d3/nvidia-ml-py3-7.352.0.tar.gz
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.7/site-packages (from gpustat->ray[rllib]) (5.6.3)
# Collecting blessings>=1.6 (from gpustat->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/03/74/489f85a78247609c6b4f13733cbf3ba0d864b11aa565617b645d6fdf2a4a/blessings-1.7-py3-none-any.whl
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.8.0->ray[rllib]) (41.4.0)
# Collecting async-timeout (from aioredis->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Collecting hiredis (from aioredis->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/32/a5/fdfd0532d078ef0fe1c0d9c742ab933336232c372ff950b98fb0f559bcdf/hiredis-1.1.0-cp37-cp37m-macosx_10_6_intel.whl
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests->ray[rllib]) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests->ray[rllib]) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests->ray[rllib]) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests->ray[rllib]) (2.8)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema->ray[rllib]) (19.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.7/site-packages (from jsonschema->ray[rllib]) (0.15.4)
# Collecting opencensus-context==0.1.2 (from opencensus->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/f1/33/990f1bd9e7ee770fc8d3c154fc24743a96f16a0e49e14e1b7540cc2fdd93/opencensus_context-0.1.2-py2.py3-none-any.whl
# Collecting google-api-core<2.0.0,>=1.0.0 (from opencensus->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/c8/3f/f7faa8a96408167c03d6fe07e2bee9b383ec18a7a1117d32912eb0c1b78f/google_api_core-1.26.0-py2.py3-none-any.whl (92kB)
#      |████████████████████████████████| 102kB 15.0MB/s ta 0:00:01
# Collecting multidict<7.0,>=4.5 (from aiohttp->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/bf/1f/6ccb2f678e6d147cc6eec00a5b8615f9fa8d8a8271cc98a2ffa0343c9063/multidict-5.1.0-cp37-cp37m-macosx_10_14_x86_64.whl (49kB)
#      |████████████████████████████████| 51kB 9.2MB/s  eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.5 in /opt/anaconda3/lib/python3.7/site-packages (from aiohttp->ray[rllib]) (3.7.4.3)
# Collecting yarl<2.0,>=1.0 (from aiohttp->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/1d/89/dc936cc5bcb25aa43620f9291f9728c6300213bbfae1b3a18fd9f0aa71c1/yarl-1.6.3-cp37-cp37m-macosx_10_14_x86_64.whl (123kB)
#      |████████████████████████████████| 133kB 27.9MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas; extra == "rllib"->ray[rllib]) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas; extra == "rllib"->ray[rllib]) (2019.3)
# Collecting pyglet<=1.5.0,>=1.4.0 (from gym[atari]; extra == "rllib"->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/70/ca/20aee170afe6011e295e34b27ad7d7ccd795faba581dd3c6f7cec237f561/pyglet-1.5.0-py2.py3-none-any.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 22.3MB/s eta 0:00:01
# Requirement already satisfied: Pillow<=7.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (7.2.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (1.2.2)
# Requirement already satisfied: opencv-python>=3. in /opt/anaconda3/lib/python3.7/site-packages (from gym[atari]; extra == "rllib"->ray[rllib]) (4.2.0.34)
# Requirement already satisfied: packaging>=14.3 in /opt/anaconda3/lib/python3.7/site-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (19.2)
# Collecting google-auth<2.0dev,>=1.21.1 (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/bf/6b/a364a4ad2a9d25904a19f53b9474ae9666b96e0653a6ca38492baf1bcf05/google_auth-1.27.0-py2.py3-none-any.whl (135kB)
#      |████████████████████████████████| 143kB 16.2MB/s eta 0:00:01
# Collecting googleapis-common-protos<2.0dev,>=1.6.0 (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib])
#   Downloading https://files.pythonhosted.org/packages/55/08/796a6bc0b550e2b7116041c953d3d5100016abea106131d71e5651826e7b/googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 26.5MB/s eta 0:00:01
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.7/site-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari]; extra == "rllib"->ray[rllib]) (0.17.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from packaging>=14.3->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (2.4.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (4.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (0.4.8)
# Building wheels for collected packages: gpustat, gym, nvidia-ml-py3
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-cp37-none-any.whl size=12621 sha256=61b22e8611fea6c32442091a62946b0409601873dcc4cf016d1df394d0420341
#   Stored in directory: /Users/test/Library/Caches/pip/wheels/48/b4/d5/fb5b7f1d040f2ff20687e3bad6867d63155dbde5a7c10f4293
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.18.0-cp37-none-any.whl size=1656452 sha256=afad29949779fcfe2664dfbe6d98453215f2c61ecd294f1af2348cb5c5a7ce14
#   Stored in directory: /Users/test/Library/Caches/pip/wheels/be/85/3b/480b828a4a697b37392740a040b8989f729d952b4e441a1877
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-cp37-none-any.whl size=19192 sha256=2665fb4e790e9d02e907f030eadd7974c94dc88f71918dfe1a19086ffc5b2b7c
#   Stored in directory: /Users/test/Library/Caches/pip/wheels/e4/1d/06/640c93f5270d67d0247f30be91f232700d19023f9e66d735c7
# Successfully built gpustat gym nvidia-ml-py3
# ERROR: google-api-core 1.26.0 has requirement six>=1.13.0, but you'll have six 1.12.0 which is incompatible.
# Installing collected packages: colorful, py-spy, msgpack, async-timeout, multidict, yarl, aiohttp, aiohttp-cors, nvidia-ml-py3, blessings, gpustat, hiredis, aioredis, redis, opencensus-context, google-auth, googleapis-common-protos, google-api-core, opencensus, lz4, tensorboardX, pyglet, atari-py, gym, dm-tree, opencv-python-headless, ray
#   Found existing installation: msgpack 0.6.1
#     Uninstalling msgpack-0.6.1:
#       Successfully uninstalled msgpack-0.6.1
#   Found existing installation: google-auth 1.17.2
#     Uninstalling google-auth-1.17.2:
#       Successfully uninstalled google-auth-1.17.2
# Successfully installed aiohttp-3.7.4 aiohttp-cors-0.7.0 aioredis-1.3.1 async-timeout-3.0.1 atari-py-0.2.6 blessings-1.7 colorful-0.5.4 dm-tree-0.1.5 google-api-core-1.26.0 google-auth-1.27.0 googleapis-common-protos-1.53.0 gpustat-0.6.0 gym-0.18.0 hiredis-1.1.0 lz4-3.1.3 msgpack-1.0.2 multidict-5.1.0 nvidia-ml-py3-7.352.0 opencensus-0.7.12 opencensus-context-0.1.2 opencv-python-headless-4.3.0.36 py-spy-0.3.4 pyglet-1.5.0 ray-1.2.0 redis-3.5.3 tensorboardX-2.1 yarl-1.6.3

# %%
# !rllib train --run=A2C --env=CartPole-v0
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# File descriptor limit 256 is too low for production servers and may result in connection errors. At least 8192 is recommended. --- Fix with 'ulimit -n 8192'
# 2021-03-02 13:19:55,948	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8265
# == Status ==
# Memory usage on this node: 11.5/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+-------+
# | Trial name                  | status   | loc   |
# |-----------------------------+----------+-------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  |       |
# +-----------------------------+----------+-------+
#
#
# (pid=64578) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64578) Instructions for updating:
# (pid=64578) non-resource variables are not supported in the long term
# (pid=64578) 2021-03-02 13:20:03,654	INFO trainer.py:616 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=64578) 2021-03-02 13:20:03,654	INFO trainer.py:643 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=64573) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64573) Instructions for updating:
# (pid=64573) non-resource variables are not supported in the long term
# (pid=64574) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64574) Instructions for updating:
# (pid=64574) non-resource variables are not supported in the long term
# (pid=64573) 2021-03-02 13:20:07,075	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64573) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64573) Instructions for updating:
# (pid=64573) If using Keras pass *_constraint arguments to layers.
# (pid=64574) 2021-03-02 13:20:07,075	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64574) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64574) Instructions for updating:
# (pid=64574) If using Keras pass *_constraint arguments to layers.
# (pid=64578) 2021-03-02 13:20:07,954	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64578) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64578) Instructions for updating:
# (pid=64578) If using Keras pass *_constraint arguments to layers.
# (pid=64578) 2021-03-02 13:20:08,751	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=64574) 2021-03-02 13:20:08,777	WARNING deprecation.py:34 -- DeprecationWarning: `env_index` has been deprecated. Use `episode.env_id` instead. This will raise an error in the future!
# == Status ==
# Memory usage on this node: 11.4/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |   ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      1 |         0.328548 |  200 |  20.4444 |                   41 |                   10 |            20.4444 |
# +-----------------------------+----------+---------------------+--------+------------------+------+----------+----------------------+----------------------+--------------------+
#
#
# (pid=64578) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=64578) Instructions for updating:
# (pid=64578) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=64573) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=64573) Instructions for updating:
# (pid=64573) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=64574) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=64574) Instructions for updating:
# (pid=64574) Prefer Variable.assign which has equivalent behavior in 2.X.
# == Status ==
# Memory usage on this node: 10.6/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      2 |           10.374 | 19000 |  36.6961 |                  152 |                    8 |            36.6961 |
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# == Status ==
# Memory usage on this node: 9.3/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      3 |          20.4447 | 37800 |  108.491 |                  200 |                   15 |            108.491 |
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 9.9/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      4 |          30.4898 | 56800 |  150.183 |                  200 |                   25 |            150.183 |
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 10.3/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      5 |          40.4897 | 75600 |  150.176 |                  200 |                   17 |            150.176 |
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 10.4/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |    ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      6 |          50.5066 | 95200 |  150.531 |                  200 |                   31 |            150.531 |
# +-----------------------------+----------+---------------------+--------+------------------+-------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 10.9/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      7 |          60.5255 | 113600 |  127.917 |                  200 |                   11 |            127.917 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 9.9/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      8 |          70.5281 | 132200 |  92.9005 |                  200 |                   10 |            92.9005 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 10.2/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |      9 |          80.5213 | 151400 |  76.9558 |                  200 |                   10 |            76.9558 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 10.7/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     10 |          90.5922 | 170000 |  71.4462 |                  200 |                   11 |            71.4462 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# == Status ==
# Memory usage on this node: 10.9/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     11 |          100.579 | 189200 |  61.9419 |                  200 |                   11 |            61.9419 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 11.0/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     12 |          110.639 | 208600 |  66.8685 |                  200 |                   11 |            66.8685 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 11.1/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     13 |          120.685 | 228000 |  72.4627 |                  200 |                   11 |            72.4627 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 9.6/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     14 |          130.676 | 245800 |  85.9807 |                  200 |                   11 |            85.9807 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 9.4/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     15 |          140.752 | 265600 |  87.2456 |                  200 |                   11 |            87.2456 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 9.6/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     16 |          150.807 | 285400 |  92.7009 |                  200 |                   13 |            92.7009 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 9.7/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     17 |          160.836 | 304800 |  104.124 |                  200 |                   12 |            104.124 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 10.3/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     18 |           170.96 | 323600 |   101.07 |                  200 |                   15 |             101.07 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# == Status ==
# Memory usage on this node: 11.0/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     19 |          181.035 | 342000 |  106.098 |                  200 |                   16 |            106.098 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 11.1/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     20 |          191.045 | 361200 |  118.362 |                  200 |                   17 |            118.362 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 11.2/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     21 |          201.114 | 380400 |  130.013 |                  200 |                   21 |            130.013 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 11.1/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     22 |           211.13 | 399200 |    126.5 |                  200 |                   20 |              126.5 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# == Status ==
# Memory usage on this node: 9.6/16.0 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects
# Result logdir: /Users/test/ray_results/default
# Number of trials: 1/1 (1 RUNNING)
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name                  | status   | loc                 |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | A2C_CartPole-v0_47f16_00000 | RUNNING  | 192.168.1.207:64578 |     23 |          221.174 | 417600 |  130.035 |                  200 |                   14 |            130.035 |
# +-----------------------------+----------+---------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# ^C

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- ---------------
# absl-py                            0.9.0
# aiohttp                            3.7.4
# aiohttp-cors                       0.7.0
# aioredis                           1.3.1
# alabaster                          0.7.12
# albumentations                     0.4.6
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# appdirs                            1.4.4
# appnope                            0.1.0
# appscript                          1.0.1
# asn1crypto                         1.0.1
# astroid                            2.3.1
# astropy                            3.2.2
# astunparse                         1.6.3
# async-timeout                      3.0.1
# atari-py                           0.2.6
# atomicwrites                       1.3.0
# attrs                              19.2.0
# autograd                           1.3
# autopep8                           1.5
# Babel                              2.7.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.5
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.8.0
# bitarray                           1.0.1
# bkcharts                           0.2
# bleach                             3.1.0
# blessings                          1.7
# bokeh                              2.2.2
# boto                               2.49.0
# Bottleneck                         1.2.1
# bqplot                             0.12.21
# Brotli                             1.0.9
# cachetools                         4.1.0
# certifi                            2019.9.11
# cffi                               1.12.3
# chardet                            3.0.4
# chart-studio                       1.1.0
# chunkify                           1.2
# Click                              7.0
# cloudpickle                        1.2.2
# clumper                            0.2.6
# clyent                             1.2.2
# colorama                           0.4.1
# colorful                           0.5.4
# conda                              4.8.5
# conda-build                        3.18.9
# conda-package-handling             1.6.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0
# cryptography                       2.7
# cvxpy                              1.0.31
# cycler                             0.10.0
# Cython                             0.29.13
# cytoolz                            0.10.0
# dash                               1.18.1
# dash-bootstrap-components          0.10.7
# dash-core-components               1.14.1
# dash-html-components               1.1.1
# dash-renderer                      1.8.3
# dash-table                         4.11.1
# dask                               2.5.2
# decorator                          4.4.0
# defusedxml                         0.6.0
# Deprecated                         1.2.10
# dill                               0.3.2
# distlib                            0.3.1
# distributed                        2.5.2
# dm-tree                            0.1.5
# docutils                           0.15.2
# ecos                               2.0.7.post1
# efficientnet-pytorch               0.6.3
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# Flask                              1.1.1
# Flask-Compress                     1.8.0
# fsspec                             0.5.2
# future                             0.17.1
# gast                               0.3.3
# geographiclib                      1.50
# geopy                              2.0.0
# gevent                             1.4.0
# glob2                              0.7
# gmpy2                              2.0.8
# google-api-core                    1.26.0
# google-auth                        1.27.0
# google-auth-oauthlib               0.4.1
# google-pasta                       0.2.0
# googleapis-common-protos           1.53.0
# gpustat                            0.6.0
# graphviz                           0.14
# greenlet                           0.4.15
# grpcio                             1.29.0
# gym                                0.18.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# hiredis                            1.1.0
# html5lib                           1.0.1
# human-learn                        0.2.0
# idna                               2.8
# imageio                            2.6.0
# imagesize                          1.1.0
# imbalanced-learn                   0.5.0
# imgaug                             0.4.0
# importlib-metadata                 0.23
# ipykernel                          5.1.2
# ipython                            7.8.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              4.3.21
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.15.1
# Jinja2                             2.10.3
# joblib                             0.13.2
# json5                              0.8.5
# jsonschema                         3.0.2
# jupyter                            1.0.0
# jupyter-client                     5.3.3
# jupyter-console                    6.0.0
# jupyter-contrib-core               0.3.3
# jupyter-contrib-nbextensions       0.5.1
# jupyter-core                       4.5.0
# jupyter-highlight-selected-word    0.2.0
# jupyter-latex-envs                 1.4.6
# jupyter-nbextensions-configurator  0.4.1
# jupyterlab                         1.1.4
# jupyterlab-server                  1.0.6
# jupyterthemes                      0.20.0
# Keras                              2.3.1
# Keras-Applications                 1.0.8
# Keras-Preprocessing                1.1.2
# keyring                            18.0.0
# kiwisolver                         1.1.0
# lazy-object-proxy                  1.4.2
# lesscpy                            0.14.0
# libarchive-c                       2.8
# lief                               0.9.0
# littleutils                        0.2.2
# llvmlite                           0.29.0
# locket                             0.2.0
# lxml                               4.4.1
# lz4                                3.1.3
# Markdown                           3.2.2
# MarkupSafe                         1.1.1
# mat73                              0.40
# matplotlib                         3.1.1
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.0.14
# mkl-random                         1.1.0
# mkl-service                        2.3.0
# mock                               3.0.5
# more-itertools                     7.2.0
# mpmath                             1.1.0
# msgpack                            1.0.2
# multidict                          5.1.0
# multipledispatch                   0.6.0
# multiprocess                       0.70.10
# munch                              2.5.0
# navigator-updater                  0.2.1
# nbconvert                          5.6.0
# nbformat                           4.4.0
# networkx                           2.3
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.0.1
# numba                              0.45.1
# numexpr                            2.7.0
# numpy                              1.17.2
# numpydoc                           0.9.1
# nvidia-ml-py3                      7.352.0
# oauthlib                           3.1.0
# olefile                            0.46
# opencensus                         0.7.12
# opencensus-context                 0.1.2
# opencv-python                      4.2.0.34
# opencv-python-headless             4.3.0.36
# openpyxl                           3.0.0
# opt-einsum                         3.2.1
# osqp                               0.6.1
# outdated                           0.2.0
# packaging                          19.2
# pandas                             0.25.1
# pandas-flavor                      0.2.0
# pandasql                           0.7.3
# pandocfilters                      1.4.2
# parso                              0.5.1
# partd                              1.0.0
# path.py                            12.0.1
# pathlib-mate                       1.0.0
# pathlib2                           2.3.5
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.7.0
# pickleshare                        0.7.5
# Pillow                             7.2.0
# pingouin                           0.3.9
# pip                                19.2.3
# pkginfo                            1.5.0.1
# plotly                             4.14.1
# pluggy                             0.13.0
# ply                                3.11
# pretrainedmodels                   0.7.4
# prometheus-client                  0.7.1
# prompt-toolkit                     2.0.10
# protobuf                           3.12.2
# psutil                             5.6.3
# ptyprocess                         0.6.0
# py                                 1.8.0
# py-spy                             0.3.4
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.5.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.3
# pydot                              1.4.1
# pydotplus                          2.0.2
# pyflakes                           2.1.1
# pyglet                             1.5.0
# Pygments                           2.4.2
# pylint                             2.4.2
# pyodbc                             4.0.27
# pyOpenSSL                          19.0.0
# pyparsing                          2.4.2
# pyrsistent                         0.15.4
# PySocks                            1.7.1
# pytest                             5.2.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.5.0
# pytest-doctestplus                 0.4.0
# pytest-html                        3.1.1
# pytest-metadata                    1.11.0
# pytest-openfiles                   0.4.0
# pytest-remotedata                  0.3.2
# python-dateutil                    2.8.0
# pytz                               2019.3
# PyWavelets                         1.0.3
# PyYAML                             5.1.2
# pyzmq                              18.1.0
# QtAwesome                          0.6.0
# qtconsole                          4.5.5
# QtPy                               1.9.0
# ray                                1.2.0
# redis                              3.5.3
# regex                              2020.6.8
# requests                           2.22.0
# requests-oauthlib                  1.3.0
# retrying                           1.3.3
# rope                               0.14.0
# rsa                                4.6
# ruamel-yaml                        0.15.46
# scikit-image                       0.15.0
# scikit-learn                       0.23.2
# scikit-lego                        0.4.4
# scikit-surprise                    1.1.0
# scipy                              1.4.1
# scs                                2.1.2
# seaborn                            0.9.0
# segmentation-models-pytorch        0.1.0
# selenium                           3.141.0
# Send2Trash                         1.5.0
# setuptools                         41.4.0
# Shapely                            1.7.1
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.12.0
# sklearn                            0.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.1.2
# sortedcontainers                   2.1.0
# soupsieve                          1.9.3
# Sphinx                             2.2.0
# sphinxcontrib-applehelp            1.0.1
# sphinxcontrib-devhelp              1.0.1
# sphinxcontrib-htmlhelp             1.0.2
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.2
# sphinxcontrib-serializinghtml      1.1.3
# sphinxcontrib-websupport           1.1.2
# spyder                             3.3.6
# spyder-kernels                     0.5.2
# SQLAlchemy                         1.3.9
# statsmodels                        0.10.1
# surprise                           0.1
# sympy                              1.4
# tables                             3.5.2
# tabulate                           0.8.7
# tblib                              1.4.0
# tensorboard                        2.2.2
# tensorboard-plugin-wit             1.6.0.post3
# tensorboardX                       2.1
# tensorflow                         2.2.0
# tensorflow-estimator               2.2.0
# termcolor                          1.1.0
# terminado                          0.8.2
# testpath                           0.4.2
# threadpoolctl                      2.1.0
# toolz                              0.10.0
# torch                              1.5.1
# torchvision                        0.6.0a0+35d732a
# tornado                            6.0.3
# tqdm                               4.36.1
# traitlets                          4.3.3
# traittypes                         0.2.1
# tweepy                             3.10.0
# typing-extensions                  3.7.4.3
# unicodecsv                         0.14.1
# urllib3                            1.24.2
# uszipcode                          0.2.4
# virtualenv                         20.4.2
# wcwidth                            0.1.7
# webencodings                       0.5.1
# Werkzeug                           0.16.0
# wheel                              0.33.6
# widgetsnbextension                 3.5.1
# wrapt                              1.11.2
# wurlitzer                          1.0.3
# xarray                             0.16.2
# xgboost                            0.90
# xlrd                               1.2.0
# XlsxWriter                         1.2.1
# xlwings                            0.15.10
# xlwt                               1.3.0
# yarl                               1.6.3
# zict                               1.0.0
# zipp                               0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
ray.rllib.agents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4dcdd9654f9c> in <module>
# ----> 1 ray.rllib.agents
#
# NameError: name 'ray' is not defined

# %%
import ray

# %%
from ray.rllib import agents
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
ray.init()
trainer = agents.a3c.A2CTrainer(env='CartPole-v0')
# Out:
# File descriptor limit 256 is too low for production servers and may result in connection errors. At least 8192 is recommended. --- Fix with 'ulimit -n 8192'
# 2021-03-02 13:25:12,170	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-03-02 13:25:14,834	INFO trainer.py:616 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# 2021-03-02 13:25:14,835	INFO trainer.py:643 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=64722) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64722) Instructions for updating:
# (pid=64722) non-resource variables are not supported in the long term
# (pid=64726) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64726) Instructions for updating:
# (pid=64726) non-resource variables are not supported in the long term
# (pid=64722) 2021-03-02 13:25:17,939	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64722) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64722) Instructions for updating:
# (pid=64722) If using Keras pass *_constraint arguments to layers.
# (pid=64726) 2021-03-02 13:25:17,956	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64726) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64726) Instructions for updating:
# (pid=64726) If using Keras pass *_constraint arguments to layers.
# 2021-03-02 13:25:18,723	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2021-03-02 13:25:19,384	WARNING util.py:47 -- Install gputil for GPU system monitoring.

# %%
config = {'gamma': 0.9,
          'lr': 1e-2,
          'num_workers': 4,
          'train_batch_size': 1000,
          'model': {
              'fcnet_hiddens': [128, 128]
          }}
trainer = agents.ppo.PPOTrainer(env='CartPole-v0', config=config)
results = trainer.train()
# Out:
# (pid=64725) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64725) Instructions for updating:
# (pid=64725) non-resource variables are not supported in the long term
# (pid=64720) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64720) Instructions for updating:
# (pid=64720) non-resource variables are not supported in the long term
# (pid=64723) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64723) Instructions for updating:
# (pid=64723) non-resource variables are not supported in the long term
# (pid=64724) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=64724) Instructions for updating:
# (pid=64724) non-resource variables are not supported in the long term
# (pid=64725) 2021-03-02 13:25:41,654	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64725) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64725) Instructions for updating:
# (pid=64725) If using Keras pass *_constraint arguments to layers.
# (pid=64720) 2021-03-02 13:25:41,654	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64720) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64720) Instructions for updating:
# (pid=64720) If using Keras pass *_constraint arguments to layers.
# (pid=64723) 2021-03-02 13:25:41,654	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64723) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64723) Instructions for updating:
# (pid=64723) If using Keras pass *_constraint arguments to layers.
# (pid=64724) 2021-03-02 13:25:41,655	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# (pid=64724) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=64724) Instructions for updating:
# (pid=64724) If using Keras pass *_constraint arguments to layers.
# 2021-03-02 13:25:42,930	WARNING deprecation.py:34 -- DeprecationWarning: `framestack` has been deprecated. Use `num_framestacks (int)` instead. This will raise an error in the future!
# 2021-03-02 13:25:45,948	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=64725) 2021-03-02 13:25:45,957	WARNING deprecation.py:34 -- DeprecationWarning: `env_index` has been deprecated. Use `episode.env_id` instead. This will raise an error in the future!
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=64725) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=64725) Instructions for updating:
# (pid=64725) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=64720) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=64720) Instructions for updating:
# (pid=64720) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=64723) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=64723) Instructions for updating:
# (pid=64723) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=64724) WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/ray/rllib/policy/tf_policy.py:928: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=64724) Instructions for updating:
# (pid=64724) Prefer Variable.assign which has equivalent behavior in 2.X.

# %%
import time
from gridworld import CliffWalkingWapper, FrozenLakeWapper, GridWorld
from agent import QLearningAgent, SarsaAgent


def run_episode(env, agent, render=False, Map=None):
    total_steps = 0
    total_reward = 0

    obs = env.reset()

    Map = ''.join(str(i) for i in Map)

    while True:
        action = agent.sample(obs)
        next_obs, reward, done, _ = env.step(action)
        if Map[next_obs] != 'G':
            reward -= 1
        if Map[next_obs] == 'H':
            reward -= 100
        if Map[next_obs] == 'G':
            reward += 1000

        agent.learn(obs, action, reward, next_obs, done)

        obs = next_obs
        total_reward += reward
        total_steps += 1
        if render:
            env.render()
        if done:
            break
    return total_reward, total_steps


def test_episode(env, agent, Map = None):
    total_reward = 0
    obs = env.reset()
    Map = ''.join(str(i) for i in Map)
    while True:
        action = agent.predict(obs)
        next_obs, reward, done, _ = env.step(action)
        if Map[next_obs] != 'G':
            reward -= 1
        if Map[next_obs] == 'H':
            reward -= 100
        if Map[next_obs] == 'G':
            reward += 1000
        total_reward += reward
        obs = next_obs
        time.sleep(0.5)
        env.render()
        if done:
            print('test reward = %.1f' % (total_reward))
            break


def main():
    # env = gym.make("FrozenLake-v0", is_slippery=False)  # 0 left, 1 down, 2 right, 3 up
    # env = FrozenLakeWapper(env)

    grid_map = ['SFFF', 'FHFH', 'FFFH', 'HFFG']
    env = GridWorld(grid_map)

    # env = gym.make("CliffWalking-v0")  # 0 up, 1 right, 2 down, 3 left
    # env = CliffWalkingWapper(env)

    agent = QLearningAgent(
        obs_n=env.observation_space.n,
        act_n=env.action_space.n,
        learning_rate=0.1,
        gamma=0.9,
        e_greed=0.2)
    # agent = SarsaAgent(
    #     obs_n=env.observation_space.n,
    #     act_n=env.action_space.n,
    #     learning_rate=0.1,
    #     gamma=0.9,
    #     e_greed=0.1)

    is_render = False
    for episode in range(500):
        ep_reward, ep_steps = run_episode(env, agent, is_render, Map=grid_map)
        print('Episode %s: steps = %s , reward = %.1f' % (episode, ep_steps,
                                                          ep_reward))


        if episode % 20 == 0:
            is_render = True
        else:
            is_render = False

    test_episode(env, agent, Map=grid_map)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cb6994b5cb3f> in <module>
#       1 import time
# ----> 2 from gridworld import CliffWalkingWapper, FrozenLakeWapper, GridWorld
#       3 from agent import QLearningAgent, SarsaAgent
#       4
#       5
#
# ModuleNotFoundError: No module named 'gridworld'
